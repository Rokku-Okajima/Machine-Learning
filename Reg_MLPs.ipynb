# %%
import torch 

if torch.cuda.is_available():
    device = "cuda"
else: 
    device = "cpu"


print(device)
# Out:
# cpu

# %%
from sklearn.datasets import load_diabetes
from sklearn.metrics import root_mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPRegressor


diabetes = load_diabetes()

X_train, X_test, y_train, y_test = train_test_split(diabetes.data, diabetes.target, random_state=42)

# %%
mlp_reg = MLPRegressor(hidden_layer_sizes=[30, 30, 30], early_stopping=True, verbose=True, random_state=42)

# %%
pipline = make_pipeline(StandardScaler(), mlp_reg)
pipline.fit(X_train, y_train)
# Out:
# Iteration 1, loss = 14353.78256838
# Validation score: -3.805972
# Iteration 2, loss = 14334.66707960
# Validation score: -3.799661
# Iteration 3, loss = 14315.34366748
# Validation score: -3.793122
# Iteration 4, loss = 14294.90227176
# Validation score: -3.786411
# Iteration 5, loss = 14274.35273356
# Validation score: -3.779355
# Iteration 6, loss = 14252.26959787
# Validation score: -3.771871
# Iteration 7, loss = 14229.46490602
# Validation score: -3.763900
# Iteration 8, loss = 14205.48986484
# Validation score: -3.755588
# Iteration 9, loss = 14180.12939342
# Validation score: -3.746777
# Iteration 10, loss = 14152.87984750
# Validation score: -3.737412
# Iteration 11, loss = 14123.35164103
# Validation score: -3.727359
# Iteration 12, loss = 14093.41906103
# Validation score: -3.716604
# Iteration 13, loss = 14059.59513297
# Validation score: -3.705205
# Iteration 14, loss = 14023.34367197
# Validation score: -3.692875
# Iteration 15, loss = 13985.07320607
# ...

# %%
mlp_reg.best_validation_score_
# Out:
# 0.6042037468525399

# %%
y_pred = pipline.predict(X_test)
rsme = root_mean_squared_error(y_test, y_pred)

# %%
rsme
# Out:
# 58.12174598480012
